# %% [markdown]
# <a href="https://colab.research.google.com/github/zmbrano1/ceri8211_S2025/blob/main/edwarzambrano_firstnotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the necessary libraries.
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a 104 X 104 matrix, A, and a 104 X 1 vector, x. Fill A and x with random numbers.

A = np.random.rand(10000, 10000)
x = np.random.rand(10000, 1)

# %%
# Perform a matrix-vector multiplication.

b = np.dot(A, x)

# %%
# Create a scatter plot of the values in vector b.

plt.scatter(range(len(b)), b, c='red')
plt.title("Scatter Plot of Vector b")
plt.xlabel("Index")
plt.ylabel("Value of b")
plt.grid(True)
plt.show()
